# %% [markdown]
# # Project #2 : Continuous Control
#
# ## DDPG Training Algorithm
#
# ---
#
# This notebook implements my solution for the Continous Control project of the [Deep Reinforcement Learning Nanodegree](https://www.udacity.com/course/deep-reinforcement-learning-nanodegree--nd893) program.
#
# I implemented the Deep Deterministic Policy Gradient (DDPG) training algorithm for the Unity Reacher environment.
#
# The code in this notebook (Continuous_Control.ipynb), the ddpg_agent.py, and model.py files is derived from the 'ddpg-pendulum' code example used in the nanodegree program. The code was modified to successfully train both the single agent and multiple agents version of the the Unity Reacher environment. The code also implements the logic to stop the training when the environment is considered solved. The project requirement is to reach an average score of 30, measured over the last 100 training episodes. In the case of the multiple agents version, the episode score is the mean of the agents' scores of the episode.

# %% [markdown]
# ### 1. Install Python Packages
#
# If you haven't done so already, run this command to install a few packages in your computing environment.  This line may take a few minutes to run!

# %%
#!pip -q install ./python

# %% [markdown]
# ### 2. Import libraries

# %%
import torch
import numpy as np
from collections import deque
#import random
import time

from unityagents import UnityEnvironment

# %% [markdown]
# ### 3. Instantiate the Unity Reacher environment

# %% [markdown]
# **_Before running the code cell below_**, change the `file_name` parameter to match the location of the Unity environment that you downloaded.
#
# - **Mac**: `"path/to/Reacher.app"`
# - **Windows** (x86): `"path/to/Reacher_Windows_x86/Reacher.exe"`
# - **Windows** (x86_64): `"path/to/Reacher_Windows_x86_64/Reacher.exe"`
# - **Linux** (x86): `"path/to/Reacher_Linux/Reacher.x86"`
# - **Linux** (x86_64): `"path/to/Reacher_Linux/Reacher.x86_64"`
# - **Linux** (x86, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86"`
# - **Linux** (x86_64, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86_64"`
#
# For instance, if you are using a Mac, then you downloaded `Reacher.app`.  If this file is in the same folder as the notebook, then the line below should appear as follows:
# ```
# env = UnityEnvironment(file_name="Reacher.app")
# ```

# %%
# on my iMac 
env = UnityEnvironment(file_name="Reacher1.app")

# in my Udacity Workspace
#env = UnityEnvironment(file_name='/data/Reacher_Linux_NoVis/Reacher.x86_64')

# on my AWS instance
#env = UnityEnvironment(file_name='./Reacher_Linux_NoVis/Reacher.x86_64')
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
# 		goal_speed -> 1.0
# 		goal_size -> 5.0
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# reset the environment and activate the training mode
env_info = env.reset(train_mode=True)[brain_name]

# number of agents
num_agents = len(env_info.agents)
print('Number of agents    :', num_agents)

# action size
action_size = brain.vector_action_space_size
print('Size of each action : ', action_size)

# state size
states = env_info.vector_observations
state_size = states.shape[1]
print('Size of each state  :', state_size)
# Out:
# Number of agents    : 1
# Size of each action :  4
# Size of each state  : 33

# %% [markdown]
# ### 4. Instantiate the Agent

# %%
from ddpg_agent import DDPG_Agent
agent = DDPG_Agent(state_size, action_size, num_agents)
# Out:
#    *****************
#    *** Using CPU ***
#    *****************

# %% [markdown]
# ### 5. Train the Agent

# %%
# training parameters
n_episodes = 5000   # maximum number of episodes
max_t = 1000        # maximum number of timesteps per episode
target_score = 30   # target score; training is complete when target score is met
window_size = 100   # number of episodes over which the average episode score is calculated
print_every = 10    # number of episodes after which the training procedures prints out a persistent update
    
# variables to track progress of the training process
scores_deque = deque(maxlen = window_size) # deque for the last window_size episode scores
scores = []                                # container for all episode scores
best_score = -np.Inf                       # the highest episode score achieved
start_time =  time.time()                  # start time, required to calculate the total training time

# training loop
for i_episode in range(1, n_episodes+1):

    # reset the environment and obtain the initial state
    env_info = env.reset(train_mode=True)[brain_name]
    states = env_info.vector_observations

    # reset the agent
    agent.reset()

    # reset the score for each Reacher agent
    agent_scores = np.zeros(num_agents)

    # run an experience, one on each Reacher agent
    for t in range(max_t):
        
        # send state to each agent and collect their action
        actions = agent.act(states)

        # send actions to the environments
        env_info = env.step(actions)[brain_name]

        # get next states
        next_states = env_info.vector_observations

        # get rewards
        rewards = env_info.rewards

        # get dones (True if agent reached the terminal state)
        dones = env_info.local_done

        # Save experiences in the replay memory,
        # and sample a batch of experiences from the replay memory to train the agent
        agent.step(states, actions, rewards, next_states, dones)
        #agent.step(states=states, actions=actions, rewards=rewards, next_states=next_states, dones=dones)

        # update the episode score and roll the states over for the next time step
        agent_scores += np.array(rewards)
        states = next_states

        if np.any(dones):
            break

    # calculate the average episode score across all agent
    episode_score = np.mean(agent_scores)

    # update the sliding window of episode scores
    scores_deque.append(episode_score)

    # append the average episode score to the scores array 
    scores.append(episode_score)

    # update the average sliding score
    average_score = np.mean(scores_deque)

    # update time the training process has lasted thus far, in minutes
    total_training_time = time.time() - start_time

    # after each episode, update the printout of the episode and sliding average scores
    print('\rEpisode {}\tScore: {:.1f}\tAverage Score: {:.1f}\tClock: {}'
        .format(i_episode, episode_score, np.mean(scores_deque), int(total_training_time)), end="")

    # after every print_every episode, print the sliding average score
    if i_episode % print_every == 0:
        print('\rEpisode {}\tScore: {:.1f}\t Average Score: {:.1f}\tClock: {}'
        .format(i_episode, episode_score, np.mean(scores_deque), int(total_training_time)))

    # save the model weights if the average episode score improved
    if (i_episode >= window_size) and (episode_score > best_score):
        torch.save(agent.actor_local.state_dict(), 'checkpoint_actor.pth')
        torch.save(agent.critic_local.state_dict(), 'checkpoint_critic.pth')
        best_score = episode_score

    if average_score >= target_score:
        print('\n\nThe agent trained in {:d} episodes! \n\n\tHighest score\t{:.0f}\n\tAverage score\t{:.1f} (measured over last {:d} episodes)\n'
              .format(i_episode - window_size, best_score, average_score, window_size))
        break
# Out:
# Episode 10	Score: 0.5	 Average Score: 0.1	Clock: 34
# Episode 20	Score: 0.0	 Average Score: 0.0	Clock: 69
# Episode 30	Score: 0.1	 Average Score: 0.0	Clock: 104
# Episode 40	Score: 0.7	 Average Score: 0.2	Clock: 139
# Episode 50	Score: 1.4	 Average Score: 0.2	Clock: 175
# Episode 60	Score: 0.3	 Average Score: 0.3	Clock: 210
# Episode 70	Score: 0.5	 Average Score: 0.3	Clock: 246
# Episode 80	Score: 0.3	 Average Score: 0.3	Clock: 282
# Episode 90	Score: 0.7	 Average Score: 0.3	Clock: 318
# Episode 100	Score: 0.3	 Average Score: 0.4	Clock: 354
# Episode 110	Score: 0.3	 Average Score: 0.4	Clock: 390
# Episode 120	Score: 0.7	 Average Score: 0.5	Clock: 426
# Episode 130	Score: 1.4	 Average Score: 0.6	Clock: 463
# Episode 140	Score: 1.9	 Average Score: 0.6	Clock: 499
# Episode 150	Score: 1.0	 Average Score: 0.7	Clock: 536
# Episode 160	Score: 0.9	 Average Score: 0.7	Clock: 573
# Episode 170	Score: 0.2	 Average Score: 0.8	Clock: 610
# Episode 180	Score: 0.7	 Average Score: 0.9	Clock: 648
# Episode 190	Score: 1.8	 Average Score: 0.9	Clock: 685
# Episode 200	Score: 1.2	 Average Score: 1.0	Clock: 722
# Episode 210	Score: 1.0	 Average Score: 1.0	Clock: 760
# Episode 220	Score: 0.3	 Average Score: 1.1	Clock: 799
# Episode 230	Score: 1.7	 Average Score: 1.1	Clock: 837
# Episode 240	Score: 0.4	 Average Score: 1.1	Clock: 875
# Episode 250	Score: 0.0	 Average Score: 1.1	Clock: 914
# Episode 260	Score: 1.1	 Average Score: 1.1	Clock: 953
# Episode 270	Score: 0.1	 Average Score: 1.0	Clock: 992
# Episode 280	Score: 0.9	 Average Score: 1.0	Clock: 1032
# Episode 290	Score: 2.9	 Average Score: 1.0	Clock: 1071
# Episode 300	Score: 0.4	 Average Score: 1.0	Clock: 1111
# Episode 310	Score: 2.3	 Average Score: 1.0	Clock: 1151
# Episode 320	Score: 0.5	 Average Score: 1.0	Clock: 1192
# Episode 330	Score: 0.2	 Average Score: 1.0	Clock: 1233
# Episode 340	Score: 1.2	 Average Score: 1.1	Clock: 1273
# Episode 350	Score: 1.1	 Average Score: 1.1	Clock: 1315
# Episode 360	Score: 1.4	 Average Score: 1.1	Clock: 1356
# Episode 370	Score: 0.2	 Average Score: 1.2	Clock: 1398
# Episode 380	Score: 2.0	 Average Score: 1.3	Clock: 1440
# Episode 390	Score: 0.8	 Average Score: 1.3	Clock: 1482
# Episode 400	Score: 1.3	 Average Score: 1.3	Clock: 1524
# Episode 410	Score: 0.3	 Average Score: 1.2	Clock: 1567
# Episode 420	Score: 1.2	 Average Score: 1.2	Clock: 1610
# Episode 430	Score: 0.6	 Average Score: 1.2	Clock: 1653
# Episode 440	Score: 3.0	 Average Score: 1.2	Clock: 1697
# Episode 450	Score: 2.1	 Average Score: 1.2	Clock: 1740
# Episode 460	Score: 1.5	 Average Score: 1.2	Clock: 1785
# Episode 470	Score: 3.1	 Average Score: 1.2	Clock: 1829
# Episode 480	Score: 1.6	 Average Score: 1.3	Clock: 1873
# Episode 490	Score: 2.5	 Average Score: 1.3	Clock: 1918
# Episode 500	Score: 1.8	 Average Score: 1.4	Clock: 1963
# Episode 510	Score: 0.8	 Average Score: 1.5	Clock: 2009
# Episode 520	Score: 3.9	 Average Score: 1.6	Clock: 2054
# Episode 530	Score: 1.2	 Average Score: 1.7	Clock: 2100
# Episode 540	Score: 2.0	 Average Score: 1.8	Clock: 2146
# Episode 550	Score: 2.5	 Average Score: 1.8	Clock: 2192
# Episode 560	Score: 1.3	 Average Score: 1.9	Clock: 2239
# Episode 570	Score: 1.1	 Average Score: 1.9	Clock: 2286
# Episode 580	Score: 3.7	 Average Score: 2.0	Clock: 2333
# Episode 590	Score: 2.2	 Average Score: 2.1	Clock: 2380
# Episode 600	Score: 3.4	 Average Score: 2.1	Clock: 2428
# Episode 610	Score: 3.8	 Average Score: 2.2	Clock: 2476
# Episode 620	Score: 2.5	 Average Score: 2.3	Clock: 2524
# Episode 630	Score: 3.6	 Average Score: 2.3	Clock: 2572
# Episode 640	Score: 2.1	 Average Score: 2.4	Clock: 2621
# Episode 650	Score: 3.8	 Average Score: 2.5	Clock: 2670
# Episode 660	Score: 2.5	 Average Score: 2.6	Clock: 2719
# Episode 670	Score: 3.3	 Average Score: 2.7	Clock: 2768
# Episode 680	Score: 3.7	 Average Score: 2.8	Clock: 2818
# Episode 690	Score: 2.5	 Average Score: 2.8	Clock: 2868
# Episode 700	Score: 5.2	 Average Score: 2.9	Clock: 2918
# Episode 710	Score: 3.6	 Average Score: 3.0	Clock: 2968
# Episode 720	Score: 3.9	 Average Score: 3.0	Clock: 3019
# Episode 730	Score: 2.6	 Average Score: 3.1	Clock: 3070
# Episode 740	Score: 3.4	 Average Score: 3.2	Clock: 3120
# Episode 750	Score: 8.0	 Average Score: 3.3	Clock: 3172
# Episode 760	Score: 2.7	 Average Score: 3.4	Clock: 3225
# Episode 770	Score: 5.9	 Average Score: 3.4	Clock: 3277
# Episode 780	Score: 4.7	 Average Score: 3.5	Clock: 3330
# Episode 790	Score: 1.4	 Average Score: 3.5	Clock: 3382
# Episode 800	Score: 2.3	 Average Score: 3.5	Clock: 3435
# Episode 810	Score: 3.5	 Average Score: 3.5	Clock: 3487
# Episode 820	Score: 3.7	 Average Score: 3.6	Clock: 3540
# Episode 830	Score: 4.7	 Average Score: 3.7	Clock: 3594
# Episode 840	Score: 2.8	 Average Score: 3.6	Clock: 3647
# Episode 850	Score: 3.1	 Average Score: 3.7	Clock: 3701
# Episode 860	Score: 2.9	 Average Score: 3.8	Clock: 3755
# Episode 870	Score: 1.2	 Average Score: 3.7	Clock: 3809
# Episode 880	Score: 2.6	 Average Score: 3.7	Clock: 3863
# Episode 890	Score: 4.1	 Average Score: 3.8	Clock: 3918
# Episode 900	Score: 5.4	 Average Score: 3.8	Clock: 3973
# Episode 910	Score: 3.3	 Average Score: 3.9	Clock: 4029
# Episode 920	Score: 2.9	 Average Score: 3.9	Clock: 4084
# Episode 930	Score: 3.4	 Average Score: 3.9	Clock: 4140
# Episode 940	Score: 2.5	 Average Score: 4.0	Clock: 4196
# Episode 950	Score: 2.6	 Average Score: 3.9	Clock: 4252
# Episode 960	Score: 7.6	 Average Score: 3.9	Clock: 4309
# Episode 970	Score: 4.3	 Average Score: 4.2	Clock: 4366
# Episode 980	Score: 9.2	 Average Score: 4.2	Clock: 4423
# Episode 990	Score: 5.2	 Average Score: 4.4	Clock: 4481
# Episode 1000	Score: 4.8	 Average Score: 4.4	Clock: 4539
# Episode 1010	Score: 7.2	 Average Score: 4.5	Clock: 4596
# Episode 1020	Score: 3.6	 Average Score: 4.7	Clock: 4654
# Episode 1030	Score: 6.3	 Average Score: 4.7	Clock: 4712
# Episode 1040	Score: 4.3	 Average Score: 4.8	Clock: 4770
# Episode 1050	Score: 6.7	 Average Score: 4.9	Clock: 4828
# Episode 1060	Score: 3.7	 Average Score: 4.8	Clock: 4886
# Episode 1070	Score: 3.6	 Average Score: 4.8	Clock: 4943
# Episode 1080	Score: 4.9	 Average Score: 4.9	Clock: 5000
# Episode 1090	Score: 3.3	 Average Score: 4.9	Clock: 5058
# Episode 1100	Score: 6.2	 Average Score: 4.9	Clock: 5115
# Episode 1110	Score: 5.2	 Average Score: 5.0	Clock: 5173
# Episode 1120	Score: 4.9	 Average Score: 5.0	Clock: 5230
# Episode 1130	Score: 8.2	 Average Score: 5.0	Clock: 5288
# Episode 1140	Score: 4.5	 Average Score: 5.1	Clock: 5346
# Episode 1150	Score: 4.0	 Average Score: 5.3	Clock: 5403
# Episode 1160	Score: 7.3	 Average Score: 5.6	Clock: 5461
# Episode 1170	Score: 6.6	 Average Score: 5.8	Clock: 5518
# Episode 1180	Score: 7.9	 Average Score: 6.0	Clock: 5576
# Episode 1190	Score: 9.0	 Average Score: 6.4	Clock: 5634
# Episode 1200	Score: 9.4	 Average Score: 6.8	Clock: 5692
# Episode 1210	Score: 3.5	 Average Score: 6.9	Clock: 5749
# Episode 1220	Score: 4.2	 Average Score: 7.0	Clock: 5807
# Episode 1230	Score: 7.4	 Average Score: 7.3	Clock: 5864
# Episode 1240	Score: 4.8	 Average Score: 7.4	Clock: 5922
# Episode 1250	Score: 7.6	 Average Score: 7.5	Clock: 5979
# Episode 1260	Score: 10.2	 Average Score: 7.7	Clock: 6037
# Episode 1270	Score: 7.7	 Average Score: 7.8	Clock: 6094
# Episode 1280	Score: 11.8	 Average Score: 7.9	Clock: 6151
# Episode 1290	Score: 9.8	 Average Score: 7.9	Clock: 6209
# Episode 1300	Score: 14.2	 Average Score: 7.9	Clock: 6267
# Episode 1310	Score: 7.7	 Average Score: 8.1	Clock: 6324
# Episode 1320	Score: 9.8	 Average Score: 8.3	Clock: 6382
# Episode 1330	Score: 9.4	 Average Score: 8.4	Clock: 6439
# Episode 1340	Score: 7.4	 Average Score: 8.5	Clock: 6497
# Episode 1350	Score: 12.2	 Average Score: 8.7	Clock: 6554
# Episode 1360	Score: 8.6	 Average Score: 8.7	Clock: 6612
# Episode 1370	Score: 8.4	 Average Score: 8.9	Clock: 6669
# Episode 1380	Score: 9.9	 Average Score: 8.8	Clock: 6727
# Episode 1390	Score: 12.9	 Average Score: 8.9	Clock: 6784
# Episode 1400	Score: 10.7	 Average Score: 8.9	Clock: 6842
# Episode 1410	Score: 9.4	 Average Score: 9.2	Clock: 6899
# Episode 1420	Score: 9.0	 Average Score: 9.2	Clock: 6957
# Episode 1430	Score: 9.8	 Average Score: 9.3	Clock: 7014
# Episode 1440	Score: 15.3	 Average Score: 9.4	Clock: 7072
# Episode 1450	Score: 9.5	 Average Score: 9.4	Clock: 7129
# Episode 1460	Score: 10.8	 Average Score: 9.6	Clock: 7187
# Episode 1470	Score: 12.2	 Average Score: 9.8	Clock: 7244
# Episode 1480	Score: 9.3	 Average Score: 10.0	Clock: 7302
# Episode 1490	Score: 15.0	 Average Score: 10.2	Clock: 7359
# Episode 1500	Score: 9.7	 Average Score: 10.4	Clock: 7417
# Episode 1510	Score: 14.3	 Average Score: 10.4	Clock: 7474
# Episode 1520	Score: 13.2	 Average Score: 10.7	Clock: 7532
# Episode 1530	Score: 7.7	 Average Score: 10.8	Clock: 7590
# Episode 1540	Score: 9.0	 Average Score: 10.8	Clock: 7647
# Episode 1550	Score: 10.6	 Average Score: 11.0	Clock: 7705
# Episode 1560	Score: 10.0	 Average Score: 10.9	Clock: 7763
# Episode 1570	Score: 10.3	 Average Score: 11.0	Clock: 7820
# Episode 1580	Score: 17.1	 Average Score: 11.1	Clock: 7878
# Episode 1590	Score: 9.2	 Average Score: 11.1	Clock: 7936
# Episode 1600	Score: 13.3	 Average Score: 11.3	Clock: 7993
# Episode 1610	Score: 11.1	 Average Score: 11.4	Clock: 8051
# Episode 1620	Score: 11.9	 Average Score: 11.6	Clock: 8109
# Episode 1630	Score: 7.0	 Average Score: 11.6	Clock: 8167
# Episode 1640	Score: 12.8	 Average Score: 11.7	Clock: 8225
# Episode 1650	Score: 15.3	 Average Score: 11.8	Clock: 8282
# Episode 1660	Score: 9.4	 Average Score: 11.9	Clock: 8340
# Episode 1670	Score: 11.6	 Average Score: 11.9	Clock: 8398
# Episode 1680	Score: 15.5	 Average Score: 11.9	Clock: 8455
# Episode 1690	Score: 11.2	 Average Score: 11.8	Clock: 8512
# Episode 1700	Score: 12.1	 Average Score: 11.8	Clock: 8570
# Episode 1710	Score: 10.4	 Average Score: 11.7	Clock: 8627
# Episode 1720	Score: 11.6	 Average Score: 11.5	Clock: 8684
# Episode 1730	Score: 10.4	 Average Score: 11.6	Clock: 8741
# Episode 1740	Score: 13.6	 Average Score: 11.7	Clock: 8799
# Episode 1750	Score: 10.5	 Average Score: 11.6	Clock: 8856
# Episode 1760	Score: 12.8	 Average Score: 11.7	Clock: 8913
# Episode 1770	Score: 12.1	 Average Score: 11.9	Clock: 8971
# Episode 1780	Score: 14.0	 Average Score: 11.9	Clock: 9028
# Episode 1790	Score: 14.2	 Average Score: 12.0	Clock: 9086
# Episode 1800	Score: 12.6	 Average Score: 12.1	Clock: 9143
# Episode 1810	Score: 12.7	 Average Score: 12.3	Clock: 9201
# Episode 1820	Score: 12.3	 Average Score: 12.3	Clock: 9259
# Episode 1830	Score: 7.8	 Average Score: 12.4	Clock: 9317
# Episode 1840	Score: 12.4	 Average Score: 12.3	Clock: 9374
# Episode 1850	Score: 15.5	 Average Score: 12.6	Clock: 9432
# Episode 1860	Score: 10.3	 Average Score: 12.5	Clock: 9490
# Episode 1870	Score: 10.7	 Average Score: 12.4	Clock: 9548
# Episode 1880	Score: 14.4	 Average Score: 12.4	Clock: 9605
# Episode 1890	Score: 13.1	 Average Score: 12.4	Clock: 9663
# Episode 1900	Score: 14.4	 Average Score: 12.4	Clock: 9721
# Episode 1910	Score: 10.4	 Average Score: 12.3	Clock: 9778
# Episode 1920	Score: 13.8	 Average Score: 12.4	Clock: 9836
# Episode 1930	Score: 10.5	 Average Score: 12.4	Clock: 9894
# Episode 1940	Score: 11.6	 Average Score: 12.4	Clock: 9951
# Episode 1950	Score: 14.3	 Average Score: 12.3	Clock: 10009
# Episode 1960	Score: 12.1	 Average Score: 12.5	Clock: 10067
# Episode 1970	Score: 18.6	 Average Score: 12.7	Clock: 10124
# Episode 1980	Score: 13.3	 Average Score: 12.9	Clock: 10182
# Episode 1990	Score: 14.3	 Average Score: 13.2	Clock: 10240
# Episode 2000	Score: 17.8	 Average Score: 13.3	Clock: 10298
# Episode 2010	Score: 11.4	 Average Score: 13.4	Clock: 10355
# Episode 2020	Score: 15.9	 Average Score: 13.6	Clock: 10413
# Episode 2030	Score: 11.8	 Average Score: 13.7	Clock: 10470
# Episode 2040	Score: 14.1	 Average Score: 13.7	Clock: 10528
# Episode 2050	Score: 13.0	 Average Score: 14.0	Clock: 10586
# Episode 2060	Score: 16.4	 Average Score: 14.0	Clock: 10643
# Episode 2070	Score: 10.5	 Average Score: 14.0	Clock: 10700
# Episode 2080	Score: 10.2	 Average Score: 14.0	Clock: 10758
# Episode 2090	Score: 15.3	 Average Score: 13.9	Clock: 10815
# Episode 2100	Score: 14.9	 Average Score: 13.9	Clock: 10873
# Episode 2110	Score: 13.2	 Average Score: 14.0	Clock: 10930
# Episode 2120	Score: 12.6	 Average Score: 13.9	Clock: 10987
# Episode 2130	Score: 13.8	 Average Score: 14.0	Clock: 11045
# Episode 2140	Score: 18.2	 Average Score: 14.2	Clock: 11102
# Episode 2150	Score: 15.3	 Average Score: 14.3	Clock: 11160
# Episode 2160	Score: 17.3	 Average Score: 14.4	Clock: 11217
# Episode 2170	Score: 16.5	 Average Score: 14.7	Clock: 11275
# Episode 2180	Score: 18.4	 Average Score: 14.8	Clock: 11332
# Episode 2190	Score: 18.4	 Average Score: 15.0	Clock: 11390
# Episode 2200	Score: 12.4	 Average Score: 15.2	Clock: 11448
# Episode 2210	Score: 19.3	 Average Score: 15.5	Clock: 11505
# Episode 2220	Score: 14.9	 Average Score: 15.7	Clock: 11563
# Episode 2230	Score: 15.8	 Average Score: 15.9	Clock: 11621
# Episode 2240	Score: 15.7	 Average Score: 16.1	Clock: 11678
# Episode 2250	Score: 18.5	 Average Score: 16.1	Clock: 11736
# Episode 2260	Score: 16.3	 Average Score: 16.4	Clock: 11794
# Episode 2270	Score: 22.6	 Average Score: 16.5	Clock: 11852
# Episode 2280	Score: 16.5	 Average Score: 16.6	Clock: 11910
# Episode 2290	Score: 17.9	 Average Score: 16.9	Clock: 11967
# Episode 2300	Score: 17.1	 Average Score: 17.1	Clock: 12024
# Episode 2310	Score: 17.8	 Average Score: 17.4	Clock: 12082
# Episode 2320	Score: 22.1	 Average Score: 17.9	Clock: 12139
# Episode 2330	Score: 18.7	 Average Score: 18.2	Clock: 12196
# Episode 2340	Score: 23.2	 Average Score: 18.7	Clock: 12254
# Episode 2350	Score: 19.8	 Average Score: 19.0	Clock: 12311
# Episode 2360	Score: 22.6	 Average Score: 19.1	Clock: 12368
# Episode 2370	Score: 18.6	 Average Score: 19.4	Clock: 12425
# Episode 2380	Score: 25.0	 Average Score: 19.6	Clock: 12483
# Episode 2390	Score: 19.3	 Average Score: 20.0	Clock: 12540
# Episode 2400	Score: 20.5	 Average Score: 20.3	Clock: 12597
# Episode 2410	Score: 18.2	 Average Score: 20.4	Clock: 12655
# Episode 2420	Score: 22.7	 Average Score: 20.3	Clock: 12712
# Episode 2430	Score: 24.7	 Average Score: 20.3	Clock: 12770
# Episode 2440	Score: 16.4	 Average Score: 20.2	Clock: 12827
# Episode 2450	Score: 17.4	 Average Score: 20.1	Clock: 12885
# Episode 2460	Score: 23.9	 Average Score: 20.4	Clock: 12942
# Episode 2470	Score: 27.0	 Average Score: 20.3	Clock: 13000
# Episode 2480	Score: 20.1	 Average Score: 20.4	Clock: 13058
# Episode 2490	Score: 25.5	 Average Score: 20.3	Clock: 13115
# Episode 2500	Score: 16.4	 Average Score: 20.3	Clock: 13173
# Episode 2510	Score: 15.9	 Average Score: 20.1	Clock: 13230
# Episode 2520	Score: 19.4	 Average Score: 20.1	Clock: 13288
# Episode 2530	Score: 15.2	 Average Score: 20.2	Clock: 13346
# Episode 2540	Score: 16.8	 Average Score: 20.3	Clock: 13403
# Episode 2550	Score: 24.2	 Average Score: 20.5	Clock: 13461
# Episode 2560	Score: 18.9	 Average Score: 20.2	Clock: 13518
# Episode 2570	Score: 22.3	 Average Score: 20.4	Clock: 13576
# Episode 2580	Score: 28.9	 Average Score: 20.5	Clock: 13633
# Episode 2590	Score: 16.8	 Average Score: 20.4	Clock: 13691
# Episode 2600	Score: 23.8	 Average Score: 20.6	Clock: 13749
# Episode 2610	Score: 21.7	 Average Score: 21.0	Clock: 13806
# Episode 2620	Score: 26.7	 Average Score: 21.3	Clock: 13864
# Episode 2630	Score: 17.3	 Average Score: 21.3	Clock: 13922
# Episode 2640	Score: 27.7	 Average Score: 21.7	Clock: 13979
# Episode 2650	Score: 23.3	 Average Score: 21.8	Clock: 14037
# Episode 2660	Score: 24.8	 Average Score: 22.0	Clock: 14094
# Episode 2670	Score: 19.5	 Average Score: 22.1	Clock: 14152
# Episode 2680	Score: 29.2	 Average Score: 22.6	Clock: 14210
# Episode 2690	Score: 24.1	 Average Score: 22.8	Clock: 14268
# Episode 2700	Score: 27.1	 Average Score: 22.9	Clock: 14325
# Episode 2710	Score: 20.2	 Average Score: 23.0	Clock: 14383
# Episode 2720	Score: 19.2	 Average Score: 22.9	Clock: 14441
# Episode 2730	Score: 16.7	 Average Score: 23.0	Clock: 14498
# Episode 2740	Score: 25.9	 Average Score: 23.0	Clock: 14556
# Episode 2750	Score: 20.3	 Average Score: 23.1	Clock: 14613
# Episode 2760	Score: 22.1	 Average Score: 23.3	Clock: 14671
# Episode 2770	Score: 26.9	 Average Score: 23.5	Clock: 14728
# Episode 2780	Score: 26.1	 Average Score: 23.2	Clock: 14786
# Episode 2790	Score: 23.3	 Average Score: 23.1	Clock: 14844
# Episode 2800	Score: 21.0	 Average Score: 23.3	Clock: 14902
# Episode 2810	Score: 26.8	 Average Score: 23.4	Clock: 14960
# Episode 2820	Score: 21.3	 Average Score: 23.7	Clock: 15017
# Episode 2830	Score: 23.0	 Average Score: 23.9	Clock: 15075
# Episode 2840	Score: 26.5	 Average Score: 23.8	Clock: 15133
# Episode 2850	Score: 29.8	 Average Score: 23.9	Clock: 15191
# Episode 2860	Score: 25.8	 Average Score: 23.8	Clock: 15249
# Episode 2870	Score: 26.7	 Average Score: 24.2	Clock: 15307
# Episode 2880	Score: 25.5	 Average Score: 24.3	Clock: 15365
# Episode 2890	Score: 25.2	 Average Score: 24.7	Clock: 15423
# Episode 2900	Score: 29.3	 Average Score: 24.7	Clock: 15480
# Episode 2910	Score: 26.7	 Average Score: 24.6	Clock: 15539
# Episode 2920	Score: 29.6	 Average Score: 24.7	Clock: 15596
# Episode 2930	Score: 27.1	 Average Score: 24.9	Clock: 15654
# Episode 2940	Score: 27.7	 Average Score: 25.2	Clock: 15712
# Episode 2950	Score: 27.6	 Average Score: 25.4	Clock: 15770
# Episode 2960	Score: 20.7	 Average Score: 25.4	Clock: 15827
# Episode 2970	Score: 24.2	 Average Score: 25.2	Clock: 15885
# Episode 2980	Score: 28.2	 Average Score: 25.3	Clock: 15943
# Episode 2990	Score: 30.2	 Average Score: 25.5	Clock: 16000
# Episode 3000	Score: 30.6	 Average Score: 25.6	Clock: 16057
# Episode 3010	Score: 33.0	 Average Score: 25.8	Clock: 16115
# Episode 3020	Score: 26.9	 Average Score: 26.0	Clock: 16172
# Episode 3030	Score: 22.9	 Average Score: 26.0	Clock: 16230
# Episode 3040	Score: 28.7	 Average Score: 26.0	Clock: 16287
# Episode 3050	Score: 28.3	 Average Score: 26.3	Clock: 16345
# Episode 3060	Score: 29.4	 Average Score: 26.5	Clock: 16402
# Episode 3070	Score: 30.7	 Average Score: 26.8	Clock: 16460
# Episode 3080	Score: 37.6	 Average Score: 27.2	Clock: 16517
# Episode 3090	Score: 35.2	 Average Score: 27.6	Clock: 16575
# Episode 3100	Score: 28.2	 Average Score: 27.7	Clock: 16632
# Episode 3110	Score: 30.4	 Average Score: 28.1	Clock: 16690
# Episode 3120	Score: 31.9	 Average Score: 28.3	Clock: 16747
# Episode 3130	Score: 25.6	 Average Score: 28.8	Clock: 16805
# Episode 3140	Score: 35.1	 Average Score: 29.2	Clock: 16863
# Episode 3150	Score: 26.8	 Average Score: 29.5	Clock: 16920
# Episode 3160	Score: 29.2	 Average Score: 29.8	Clock: 16977
# Episode 3170	Score: 31.7	 Average Score: 29.9	Clock: 17035
# Episode 3173	Score: 31.7	Average Score: 30.0	Clock: 17052
#
# The agent trained in 3073 episodes!
#
# 	Highest score	38
# 	Average score	30.0 (measured over last 100 episodes)

# %%
env.close()

# %% [markdown]
# ### 6. Plot and save the Training Curve

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(figsize=(12, 6))
fig.suptitle("Learning Curve", fontsize=15)
ax.plot(np.arange(1, len(scores)+1), scores, color="forestgreen", label="line")
plt.xlim(left=1)
plt.ylim(bottom=0)
ax.set_xlabel("Episode")
ax.set_ylabel("Score")
ax.grid(True)
ax.grid(b=True, which='major', color='gray', linestyle='-', linewidth=0.75)
ax.minorticks_on()
ax.grid(b=True, which='minor', color='gray', linestyle='-', alpha=.75, linewidth=0.25)
plt.show()

#  save plot to a file
fig.savefig("ddpg_agent_learning_curve.jpg")
